# %% [markdown]
# DAY 1 – Python for Data Science (Core)

# %%
nums = [1,2,3,4,5]
squares = [x*x for x in nums if x % 2 == 0]
print(squares)

def stats(x):
    return min(x), max(x), sum(x)/len(x)

print(stats(nums))
# Out:
# [4, 16]
# (1, 5, 3.0)

# %% [markdown]
# DAY 2 – NumPy (Numerical Thinking)

# %%
import numpy as np

arr = np.random.randint(1, 100, (3,3))
print(arr)
print("Row mean:", arr.mean(axis=1))
print("Column sum:", arr.sum(axis=0))
# Out:
# [[37 92 42]
#  [91 25 70]
#  [15  4 56]]
# Row mean: [57. 62. 25.]
# Column sum: [143 121 168]

# %% [markdown]
# DAY 3 – Pandas (Real Data Handling)

# %%
import pandas as pd

df = pd.DataFrame({
    "Dept": ["IT","HR","IT","HR"],
    "Salary": [50000,60000,55000,58000]
})

print(df.groupby("Dept")["Salary"].mean())
# Out:
# Dept
# HR    59000.0
# IT    52500.0
# Name: Salary, dtype: float64

# %% [markdown]
# DAY 4 – Data Visualization

# %%
import matplotlib.pyplot as plt

data = [12,15,14,10,18,20]
plt.hist(data)
plt.title("Distribution")
plt.show()

# %% [markdown]
# DAY 5 – Statistics for DS

# %%
import numpy as np

data = np.random.normal(50, 10, 1000)
print("Mean:", np.mean(data))
print("Std:", np.std(data))
# Out:
# Mean: 50.07371359118228
# Std: 10.325461975697259

# %% [markdown]
# DAY 6 – Machine Learning Basics

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# DAY 7 – End-to-End Mini Pipeline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.9473684210526315
